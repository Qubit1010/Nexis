# %% [markdown]
# <p align="center">
# <img src="https://raw.githubusercontent.com/ShayanRiyaz/My-Technical-Workshops/master/Deep-Learning-Robotics-Workshop/assets/Cover-Photo.png">
# </p>

# %% [markdown]
# # <h1 align="center">Deep Learning and Robotics Using TensorFlow and Unity</h1>
# #### <h4 align="center">*By Shayan Riyaz*</h4>

# %% [markdown]
# *Special shoutout to [Biswajit Sahoo](https://biswajitsahoo1111.github.io/) and [Alexandre Ribard](https://github.com/AlexRibard)* who helped me throughout the Machine Learning part of the project.

# %% [markdown]
# # <h1 align="center">Project</h1>

# %% [markdown]
# <p align="center">
# <img src="https://raw.githubusercontent.com/ShayanRiyaz/My-Technical-Workshops/master/Deep-Learning-Robotics-Workshop/assets/Arduino.png" width="100">
# </p>

# %% [markdown]
# <p align="center">
# <img src="https://raw.githubusercontent.com/ShayanRiyaz/My-Technical-Workshops/master/Deep-Learning-Robotics-Workshop/assets/controller.jpeg" width="300">
# </p>

# %% [markdown]
# ## Problem Statement
#
# The project intially started as a research project that involved analyzing the learning time taken to understand sign language. For reference I wrote a small notebook for it and uploaded it to Kaggle. You can find it [here](https://www.kaggle.com/shayanriyaz/gesture-classification-using-machine-learning).
#
#
# Our goal for this project was to use the the glove shown above as a controller for a game. This was achieved successfully by using Sensor Fusion to decrease the drift in our IMUs and TensorFlow as our framework for the Deep Learning Model.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Intertial Measurment Units
#
# The Inertial Measurment Unit's used for this project were custom designed by a professor at California State University, Long Beach.
#
#
# **What is an IMU?**
#
# An IMU is a specific type of sensor that measures angular rate, force and sometimes magnetic field. IMUs are composed of a 3-axis accelerometer and a 3-axis gyroscope, which would be considered a 6-axis IMU. They can also include an additional 3-axis magnetometer, which would be considered a 9-axis IMU.
#
# Technically, the term “IMU” refers to just the sensor, but IMUs are often paired with sensor fusion software which combines data from multiple sensors to provide measures of orientation and heading. In common usage, the term “IMU” may be used to refer to the combination of the sensor and sensor fusion software. You can read more abou IMUs [here](https://www.ceva-dsp.com/ourblog/what-is-an-imu-sensor/).
#
# <p align="center">
# <img src="https://www.ceva-dsp.com/ourblog/wp-content/uploads/sites/3/2018/11/HIL-What-is-an-IMU-wk-1.jpg" width="500">
# </p>

# %% [markdown]
# ###  Artifical Intelligence Model
#
# Since our case was specific, we trained, what we call, a **Narrow AI**.
#
# **What is a Narrow AI?**
#
# Narrow AI is a term used to describe artificial intelligence systems that are specified to handle a singular or limited task. The antithesis to Narrow AI, sometimes referred to as weak AI, is called strong AI. Strong AI, unlike Narrow AI, is capable of handling a wide range of tasks rather than one particular task or problem. This variation of artificial intelligence can be roughly conceptualized as a foundation for neural networks emulating sentience or consciousness.
#
# <p align="center">
# <img src="https://images.deepai.org/django-summernote/2019-05-24/a5359efc-56f2-4ed6-b435-ecae23e51310.png">
# </p>

# %% [markdown]
# ### Where I went to Look for Help *(yeah...)*
# - **GitHub Issues**
#   - [Barracuda - Issue - 39](https://github.com/Unity-Technologies/barracuda-release/issues/39)
#   - [Barracuda - Issue - 32](https://github.com/Unity-Technologies/barracuda-release/issues/32)
#   - [Onnx - Discussion - 2745](https://github.com/onnx/onnx/discussions/2745)
# - **Stack Overflow**
#   - [Create a new txt file instead of appending in c sharp](https://stackoverflow.com/questions/61197164/create-a-new-txt-file-instead-of-appending-in-c-sharp)
#   - [How to read a csv file and create a new csv file after every nth number of rows](https://stackoverflow.com/questions/61263726/how-to-read-a-csv-file-and-create-a-new-csv-file-after-every-nth-number-of-rows)
#   - [How to parse a string stream from pyser al and compare with a pre specified value](https://stackoverflow.com/questions/60405560/how-to-parse-a-string-stream-from-pyserial-and-compare-with-a-pre-specified-value)
#   - [Function to find available serial port and open it for unity](https://stackoverflow.com/questions/61198354/function-to-find-available-serial-port-and-open-it-for-unity)
#   - [Increment file everytime script is called c sharp](https://stackoverflow.com/questions/61237915/increment-file-everytime-script-is-called-c-sharp)
#   - [How to make a prediction with the tensorflow model and frozen-graph](https://stackoverflow.com/questions/61334223/how-to-make-a-prediction-with-the-tensorflow-model-and-frozen-graph)
#   - [Convert jagged string to jagged float](https://stackoverflow.com/questions/61583092/convert-jagged-string-to-jagged-float)
#
#
# **In addition to this I also had email exchanges with multiple people who helped me understand TensorFlow and Unity better.**

# %% [markdown]
# # <h1 align="center">Data Preprocessing and Ingestion</h1>
#
# <p align="center">
# <img src="https://upload.wikimedia.org/wikipedia/commons/thumb/0/05/Scikit_learn_logo_small.svg/1200px-Scikit_learn_logo_small.svg.png" width="200">
# </p>
#
# *I won't be covering the data preprocessing in this notebook, however I have uploaded a repository on GitHub where I wrote a program to prepare my data.*

# %% [markdown]
# <p align="center">
# <img src="https://drive.google.com/uc?export=view&id=1nmPAgvtZFeOm7E7bzP-WOYSeVz-2St6I" width="100">
#
# <a href="https://raw.githubusercontent.com/ShayanRiyaz/My-Technical-Workshops/master/Deep-Learning-Robotics-Workshop/assets/GitHub.png" ><p align="center">Excel Bulk Processor</p></a>
#
# </p>

# %%
import os
import glob
import numpy as np
np.random.seed(42) # Answer to the ultimate question

# %% [markdown]
# ### Checking the data

# %%
# !unzip /content/drive/My\ Drive/Deep-Learning-Robotics-Presentation/data/Unity_Data
# Out:
# unzip:  cannot find or open /content/drive/My Drive/Deep-Learning-Robotics-Presentation/data/Unity_Data, /content/drive/My Drive/Deep-Learning-Robotics-Presentation/data/Unity_Data.zip or /content/drive/My Drive/Deep-Learning-Robotics-Presentation/data/Unity_Data.ZIP.

# %%
# !ls '/content/drive/My Drive/'
# Out:
# '10 Days.gdoc'
# '10 Holidays.gdoc'
#  1682885661019.mp4
#  1685289490891.mp4
#  1689293628024.mp4
#  1697113135915.mp4
# '2023-08-06 19-29-55.mkv'
# '2023-08-10 21-00-17.mkv'
# '2023-12-04 22-38-02.mkv'
#  2026-03-21-ai-agents-got-scary-good-at-real-work.gdoc
# '25 - Fall Schedule.gdoc'
# '2 M Gs.gdoc'
# '2 Months Goals.gdoc'
# '3 Days from Exams.gdoc'
#  4-MS.gdoc
# 'Abbas MVP (1).gdoc'
# 'Abbas MVP.gdoc'
#  Account_Statement_12-05-2025T15_39_24.gdoc
#  Account_Statement_12-05-2025T15_39_24.pdf
#  Account_Statement_18-04-2025T18_11_25.gdoc
#  Account_Statement_18-04-2025T18_11_25.pdf
#  Account_Statement_30-05-2025T21_46_20.gdoc
#  Account_Statement_30-05-2025T21_46_20.pdf
# 'A Directory of Women Doing Kick-Ass Shit! (1).png'
# 'A Directory of Women Doing Kick-Ass Shit! (2).png'
# 'A Directory of Women Doing Kick-Ass Shit!.png'
# 'Agency Operation Subscriptions.gsheet'
#  AI_Agents_Report.gdoc
# 'AI and Cultural & Social Change.gdoc'
# 'AI Bank Statement Converter Project.gdoc'
# 'AI Brief - Feb 26 (Fixed Links).gdoc'
# 'AI Business Brief: Trends, Funding, Policy.gdoc'
# 'AI & Business Daily Brief - Feb 26, 2026.gdoc'
# 'AI & Business Daily Brief - Feb 26 (Formatted).gdoc'
# 'AI Crash Course.gdoc'
# 'AI Daily Brief - Feb 26 (Complete) (1).gdoc'
# 'AI Daily Brief - Feb 26 (Complete).gdoc'
# 'AI Daily Brief - Feb 26 (Final).gdoc'
# 'AI Daily Brief - Feb 26 (Professional).gdoc'
# 'AI_Robotics_Lab_Exam_Aleem_Ul_Hassan(42490).gdoc'
# 'AI_Robotics_Lab_Exam_Zaid_Tayyab(39703).gdoc'
# 'AI Robotics Quiz 1 .gdoc'
# 'AI Robotics Quiz 2.gdoc'
# 'AI Robotics Quiz_Lab_2.gdoc'
# 'A.I. Will Transform the Global Economy - The.png'
# 'Aleem 65951.gdoc'
# 'Aleem 65951.pdf'
# 'Aleem H. - Full Stack Developer | React,.png'
# 'Aleem Ul hassan.pdf'
# 'Ali SE.gdoc'
# 'AMELIA - Essence Picture.png'
#  apify-google-map_9-4-26.csv
#  apify-google-map_9-4-26.gsheet
#  apollo-contacts-export.csv
# 'Artificial Intelligence and Economic Transformation.gslides'
# 'Assignment 3 SE Ahmed.gdoc'
# 'Assignment tracker.gsheet'
# 'B2B AI Automation Specialist Project.gdoc'
# 'BandJam Website Things Left .gdoc'
# 'Becoming an ECA Support Worker .pdf'
# 'Blue and White Background Simple Resume  (1).gdoc'
#  Books
# 'Breaking News in Avalon | Stone Harbor | Cape.png'
# 'CamScanner 11-26-2023 13.30.jpg'
# 'Case-Study || Chimi Sunglasses.png'
# 'Colab Notebooks'
#  cold-email_9-4-26.csv
# 'Cold Email Outreach Tool | Unlimited.png'
# 'Company Brief.gdoc'
# 'Content Editorial Calendar .gsheet'
# 'Copy of AI Tech Agency Infographics by Slidesgo.gslides'
# 'Copy of Cyber-Futuristic AI Technology Thesis Defense by Slidesgo.gslides'
# 'Copy of FRAMER.gdoc'
# 'Copy of How to get High Ticket Clients from Linkedin Search.gdoc'
# 'Course Schedule .gdoc'
# 'Culture fair intelligence test | 123test (1).com.png'
# 'Culture fair intelligence test | 123test.com.png'
#  CV.gdoc
#  dataset_linkedin-jobs-scraper_2026-03-30_22-32-01-971.gsheet
#  dataset_linkedin-jobs-scraper_2026-03-30_22-50-08-627.gsheet
# 'Dataset Statistics and Interactive Analysis.gdoc'
# 'DBMS LAB-1.gdoc'
# 'DBMS Lab Final Abdul Basit - 39707.gdoc'
# 'DBMS Lab Final Ali.gdoc'
# 'DBMS Lab Final.gdoc'
# 'DBMS LAB-TASK-2.gdoc'
# 'DCCN Assignment #2.gdoc'
# 'DCCN Assignment.gdoc'
# 'Development Plan (French).gdoc'
# 'Development Plan.gdoc'
#  Docs
# 'DSA Exam.gdoc'
# 'Dummy Data.gsheet'
# 'EcoVerse eCommerce Platform - DBMS Project Report.gdoc'
#  EHC_pdf_merged.pdf
# 'Extracting PDF Debit Transactions for Google Sheet.gsheet'
# 'Extract PDF Bank Transactions to Google Sheet.gsheet'
# ' Fabrizio Meeting.gdoc'
# 'Final LAB Paper DBMS.gdoc'
# 'Finals Exam Schedule.gdoc'
# 'Fire Emblem Engage Tier List.gsheet'
# 'Float Group | Careers.png'
# 'Float Group | Home.png'
# 'Float Group | Portfolio (1).png'
# 'Float Group | Portfolio (2).png'
# 'Float Group | Portfolio.png'
# 'Form Reach.gsheet'
# 'Framer Test Project.gdoc'
#  FS-Starting-with-support-coord-PDF.pdf
# 'Gemini Export 28 February 2026 at 12:42:20 GMT+5.gdoc'
# 'Gemini Export 31 January 2026 at 17:10:16 GMT+5.gsheet'
# 'Gemini export 7 June 2025 at 15:37:10 GMT+5.gdoc'
# 'Gemini Gems'
# 'Goals List .gdoc'
# 'Grande Experiences.png'
# 'Habits Scorecard.gdoc'
# 'Habit Stacking.gdoc'
# 'Home Page Issues.gdoc'
# 'Home Simple – Kaazi'\''s Wear (1).png'
# 'Home Simple – Kaazi'\''s Wear (2).png'
# "Home Simple – Kaazi's Wear.png"
# 'How Artificial Intelligence is Redefining the Global Economy.pdf'
# 'How to get High Ticket Clients from Linkedin Search.gdoc'
# 'How to implement AI practically.gdoc'
# 'https:  youtu.be OOO_x3Oh2nE?si=ocSjhyIbheh0mRxP.gdoc'
# "I am sharing 'Scan 26 Nov 23 11·49·30' with you.pdf"
#  Identity.gdoc
#  IMG_20230722_010932_716.jpg
#  IMG_20230907_161503_615.jpg
#  IMG_20230907_161639_710.jpg
#  IMG_20230907_161827_430.jpg
#  IMG_20230907_162113_314.jpg
#  IMG_20231126_132247_681.jpg
#  IMG_20231126_132707_962.jpg
# 'Impactful Projects.gdoc'
# 'Instagram Content Profiles.gsheet'
#  Instagram-data_15-4-26_2.csv
#  Instagram-data_15-4-26_2.gsheet
#  Instagram-data_15-4-26_3.csv
#  Instagram-data_15-4-26_3.gsheet
#  Instagram-data_15-4-26_4.csv
#  Instagram-data_15-4-26_4.gsheet
#  instagram-data_15-4-26.csv
#  instagram-data_15-4-26.gsheet
#  instagram-data_9-4-26.csv
# 'Instagram Videos.gsheet'
# 'International IQ Register.png'
#  Introduction.gslides
# 'IU Learning Management System.png'
# 'K-Nearest Neighbors (KNN) with k-Fold Cross-Validation.gdoc'
# 'Lab Assignment OOP.gdoc'
# 'Lab Task 1 Assignment.pdf'
# 'Lecture 2 Practice Problems.gdoc'
#  linkedin-data_15-4-26_2.csv
#  linkedin-data_15-4-26_3.csv
#  linkedin-data_15-4-26_4.csv
#  linkedin-data_15-4-26_4.gsheet
#  linkedin-data_15-4-26.csv
#  linkedin-data_15-4-26.gsheet
#  linkedin-data.csv
#  linkedin-data_test.csv
#  linkedin-leads.gsheet
# 'Linux Command Cheat Sheet.pdf'
# 'LLMs: Mechanics, Breakthroughs, and Verdict.gdoc'
# 'Lostinfluence | A Full Service Influencer (1).png'
# 'Lostinfluence | A Full Service Influencer.png'
# 'Lostinfluence || Home.png'
# 'Marcus Aurelius (Emperor of Rome), Martin Hammond, Diskin Clay Meditations  .pdf'
# 'mcc (1).gdoc'
#  mcc.gdoc
# 'Mids Exam Schedule.gdoc'
# 'Mids Exam Schedule Spring 2025.gdoc'
# 'Moji Blackhole Animation.gdoc'
#  Monthly
# 'Monthly budget.gsheet'
# 'My results from the BigFive personality test .png'
# 'n8n Templates.gsheet'
# 'Naive Bayes Classification.gdoc'
# 'naqeeb uni.gdoc'
# 'Neural networks 3Blue1Brown.gdoc'
#  Nexis.gdoc
# 'NexusPoint Executive Summary.gdoc'
# 'NexusPoint Projects & Team.gsheet'
# 'NexusPoint Services Questionnaire.gform'
# 'NexusPoint Website Audits'
# 'Noah Levy — Art, Illustration & Murals.png'
# 'Nucleairs | Mediaproductiebedrijf.png'
# 'OOP Assignment.gdoc'
# 'OOP Lab manual Miss Umat ul Shaiyah.gdoc'
# 'OOP Lab Project.gdoc'
# 'OpenClaw: The Architecture of the Agentic Economy.gdoc'
# 'Outbound Copywriting: Psychology & Strategy.gdoc'
# 'Pak Studies Book Review.gdoc'
#  pard.png
#  persuadingsapphire_36x24.gslides
# 'Prior to this class, my communication resembled a ball of yarn – the ideas were there, but untangling them into concise, intelligible messages was a struggle.gdoc'
# 'Private Jet Requirements .gdoc'
#  Prob.gdoc
# 'Project Outline.gdoc'
# 'Proposal (1).gdoc'
# 'Proposal About.gdoc'
#  Proposal.gdoc
# "Quiet- The Power of Introverts in a World That Can't Stop Talking - Susan Cain.pdf"
# 'Quiz PDF.gdoc'
# 'Quote for Vivid Vision Activator™ Development Framer.gdoc'
# 'README documentation.gdoc'
#  Report.gdoc
# 'Research Topics'
#  Resume.gdoc
# 'Screenshot 2023-12-20 050000.png'
# 'Si Her Web3 Talent Collective.png'
# 'SOTAGROVE | Midwest Based Digital Marketing.png'
# 'SOTAGROVE | Ovosk Med Spa (1).png'
# 'SOTAGROVE | Ovosk Med Spa.png'
# 'stdin test doc.gdoc'
# 'STEAMid: Curated for You.png'
# 'STEAMid Review.gdoc'
#  Study
#  Superintelligence.png
# 'Tackling Career and Personal Challenges.gdoc'
# 'T A & Q.gdoc'
#  Test.gsheet
# 'The Framer Landing Page Acceleration System — Proposal.gdoc'
# 'THE LUME Melbourne.png'
# 'The Q1 Lead Autopilot 30-Day System — Proposal for Acme Corp (1).gdoc'
# 'The Q1 Lead Autopilot 30-Day System — Proposal for Acme Corp.gdoc'
# 'things do right now.gdoc'
# 'Timeline: 4-6 weeks.gdoc'
# 'Transfer Application.gdoc'
# 'UFC results.gsheet'
#  Unity_Data.zip
# 'University Research Notes'
# 'Untitled document (10).gdoc'
# 'Untitled document (11).gdoc'
# 'Untitled document (12).gdoc'
# 'Untitled document (13).gdoc'
# 'Untitled document (14).gdoc'
# 'Untitled document (15).gdoc'
# 'Untitled document (16).gdoc'
# 'Untitled document (17).gdoc'
# 'Untitled document (18).gdoc'
# 'Untitled document (19).gdoc'
# 'Untitled document (1).gdoc'
# 'Untitled document (20).gdoc'
# 'Untitled document (21).gdoc'
# 'Untitled document (2).gdoc'
# 'Untitled document (3).gdoc'
# 'Untitled document (4).gdoc'
# 'Untitled document (5).gdoc'
# 'Untitled document (6).gdoc'
# 'Untitled document (7).gdoc'
# 'Untitled document (8).gdoc'
# 'Untitled document (9).gdoc'
# 'Untitled document.gdoc'
# 'Untitled form.gform'
# 'Untitled presentation.gslides'
# 'Untitled project.gscript'
# 'Untitled spreadsheet (1).gsheet'
# 'Untitled spreadsheet (2).gsheet'
# 'Untitled spreadsheet (3).gsheet'
# 'Untitled spreadsheet.gsheet'
# 'upwork bidding.gdoc'
# 'Upwork Proposal - Web Dev - 21 04 2026 (1).gdoc'
# 'Upwork Proposal - Web Dev - 21 04 2026.gdoc'
# 'Upwork RSS.gsheet'
#  VID-20231208-WA0011.mp4
#  VID-20231208-WA0012.mp4
#  VID-20231208-WA0014.mp4
# 'Vivid Vision Activator™ Development Custom Development in NextJs.gdoc'
# 'Vouge Paris Apartments - Gringo - Webflow.png'
# 'Webflow Proposal for Service Businesses.gdoc'
# 'Webflow Website Proposal for Service Businesses.gdoc'
# 'Web Proposal Templates.gdoc'
# 'Website Issues.gdoc'
# 'Website Redesign Proposal — Staffing Agency.gdoc'
# 'Website SEO & Visibility Plan for both websites.gsheet'
# 'Website SEO & Visibility Plan.gdoc'
#  website_strategy_nexuspoint_20260105_115557.gdoc
#  When_To_Cut_A_Friend_720P.mp4
#  Work
# 'Zavia Project Proposal.gdoc'

# %%
# !unzip '/content/drive/My Drive/Unity_Data.zip' -d /content/
# Out:
# Archive:  /content/drive/My Drive/Unity_Data.zip
#    creating: /content/Unity_Data/
#    creating: /content/Unity_Data/.ipynb_checkpoints/
#   inflating: /content/Unity_Data/.ipynb_checkpoints/Single_Csv_to_Multi_Csv-checkpoint.ipynb
#    creating: /content/Unity_Data/Crawl/
#   inflating: /content/Unity_Data/Crawl/Crawl_001.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_002.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_003.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_004.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_005.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_006.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_007.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_008.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_009.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_010.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_011.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_012.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_013.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_014.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_015.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_016.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_017.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_018.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_019.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_020.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_021.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_022.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_023.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_024.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_025.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_026.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_027.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_028.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_029.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_030.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_031.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_032.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_033.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_034.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_035.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_036.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_037.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_038.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_039.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_040.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_041.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_042.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_043.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_044.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_045.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_046.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_047.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_048.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_049.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_050.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_051.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_052.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_053.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_054.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_055.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_056.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_057.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_058.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_059.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_060.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_061.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_062.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_063.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_064.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_065.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_066.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_067.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_068.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_069.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_070.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_071.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_072.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_073.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_074.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_075.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_076.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_077.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_078.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_079.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_080.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_081.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_082.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_083.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_084.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_085.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_086.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_087.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_088.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_089.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_090.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_091.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_092.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_093.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_094.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_095.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_096.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_097.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_098.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_099.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_100.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_101.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_102.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_103.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_104.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_105.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_106.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_107.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_108.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_109.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_110.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_111.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_112.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_113.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_114.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_115.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_116.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_117.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_118.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_119.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_120.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_121.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_122.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_123.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_124.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_125.csv
#   inflating: /content/Unity_Data/Crawl/Crawl_126.csv
#   inflating: /content/Unity_Data/Crawl/Crawl
#   inflating: /content/Unity_Data/Forward/Forward_386.csv
#   inflating: /content/Unity_Data/Forward/Forward_387.csv
#   inflating: /content/Unity_Data/Forward/Forward_388.csv
#   inflating: /content/Unity_Data/Forward/Forward_389.csv
#   inflating: /content/Unity_Data/Forward/Forward_390.csv
#   inflating: /content/Unity_Data/Forward/Forward_391.csv
#   inflating: /content/Unity_Data/Forward/Forward_392.csv
#   inflating: /content/Unity_Data/Forward/Forward_393.csv
#   inflating: /content/Unity_Data/Forward/Forward_394.csv
#   inflating: /content/Unity_Data/Forward/Forward_395.csv
#   inflating: /content/Unity_Data/Forward/Forward_396.csv
#   inflating: /content/Unity_Data/Forward/Forward_397.csv
#   inflating: /content/Unity_Data/Forward/Forward_398.csv
#   inflating: /content/Unity_Data/Forward/Forward_399.csv
#   inflating: /content/Unity_Data/Forward/Forward_400.csv
#    creating: /content/Unity_Data/Grab/
#   inflating: /content/Unity_Data/Grab/Grab_001.csv
#   inflating: /content/Unity_Data/Grab/Grab_002.csv
#   inflating: /content/Unity_Data/Grab/Grab_003.csv
#   inflating: /content/Unity_Data/Grab/Grab_004.csv
#   inflating: /content/Unity_Data/Grab/Grab_005.csv
#   inflating: /content/Unity_Data/Grab/Grab_006.csv
#   inflating: /content/Unity_Data/Grab/Grab_007.csv
#   inflating: /content/Unity_Data/Grab/Grab_008.csv
#   inflating: /content/Unity_Data/Grab/Grab_009.csv
#   inflating: /content/Unity_Data/Grab/Grab_010.csv
#   inflating: /content/Unity_Data/Grab/Grab_011.csv
#   inflating: /content/Unity_Data/Grab/Grab_012.csv
#   inflating: /content/Unity_Data/Grab/Grab_013.csv
#   inflating: /content/Unity_Data/Grab/Grab_014.csv
#   inflating: /content/Unity_Data/Grab/Grab_015.csv
#   inflating: /content/Unity_Data/Grab/Grab_016.csv
#   inflating: /content/Unity_Data/Grab/Grab_017.csv
#   inflating: /content/Unity_Data/Grab/Grab_018.csv
#   inflating: /content/Unity_Data/Grab/Grab_019.csv
#   inflating: /content/Unity_Data/Grab/Grab_020.csv
#   inflating: /content/Unity_Data/Grab/Grab_021.csv
#   inflating: /content/Unity_Data/Grab/Grab_022.csv
#   inflating: /content/Unity_Data/Grab/Grab_023.csv
#   inflating: /content/Unity_Data/Grab/Grab_024.csv
#   inflating: /content/Unity_Data/Grab/Grab_025.csv
#   inflating: /content/Unity_Data/Grab/Grab_026.csv
#   inflating: /content/Unity_Data/Grab/Grab_027.csv
#   inflating: /content/Unity_Data/Grab/Grab_028.csv
#   inflating: /content/Unity_Data/Grab/Grab_029.csv
#   inflating: /content/Unity_Data/Grab/Grab_030.csv
#   inflating: /content/Unity_Data/Grab/Grab_031.csv
#   inflating: /content/Unity_Data/Grab/Grab_032.csv
#   inflating: /content/Unity_Data/Grab/Grab_033.csv
#   inflating: /content/Unity_Data/Grab/Grab_034.csv
#   inflating: /content/Unity_Data/Grab/Grab_035.csv
#   inflating: /content/Unity_Data/Grab/Grab_036.csv
#   inflating: /content/Unity_Data/Grab/Grab_037.csv
#  './Unity_Data/Crawl/Crawl_009.csv']

# %% [markdown]
# - To train a model you have to create a `training set` and a `test_set`
# - You will also create a `validation set`.  .
#
# - Usually `training set` contains 75% of the whole data and `test set` contains rest.
# - Also, `training set` should contain data pertaining to each gesture. Here is how we do it.
# - Before we divide your data into training and test set, make sure to shuffle it first.
# - For splitting we will `train_test_split` of `scikit-learn` that automatically shuffles the file names.

# %%
Craw_files = glob.glob("./Unity_Data/Crawl/*")
Forw_files = glob.glob("./Unity_Data/Forward/*")
Grab_files = glob.glob("./Unity_Data/Grab/*")
Left_files = glob.glob("./Unity_Data/Left/*")
Papr_files = glob.glob("./Unity_Data/Paper/*")
Righ_files = glob.glob("./Unity_Data/Right/*")
Rock_files = glob.glob("./Unity_Data/Rock/*")
Scis_files = glob.glob("./Unity_Data/Scissors/*")
Uppp_files = glob.glob("./Unity_Data/Uppp/*")
Wave_files = glob.glob("./Unity_Data/Wave/*")

# %% [markdown]
# Now, from each gesture type we will select 75% files for trianing and rest for testing.

# %%
from sklearn.model_selection import train_test_split

# %%
Craw_train, Craw_test = train_test_split(Craw_files, test_size = .25, random_state = 42)
Forw_train, Forw_test = train_test_split(Forw_files, test_size = .25, random_state = 42)
Grab_train, Grab_test = train_test_split(Grab_files, test_size = .25, random_state = 42)
Left_train, Left_test = train_test_split(Left_files, test_size = .25, random_state = 42)
Papr_train, Papr_test = train_test_split(Papr_files, test_size = .25, random_state = 42)
Righ_train, Righ_test = train_test_split(Righ_files, test_size = .25, random_state = 42)
Rock_train, Rock_test = train_test_split(Rock_files, test_size = .25, random_state = 42)
Scis_train, Scis_test = train_test_split(Scis_files, test_size = .25, random_state = 42)
Uppp_train, Uppp_test = train_test_split(Uppp_files, test_size = .25, random_state = 42)
Wave_train, Wave_test = train_test_split(Wave_files, test_size = .25, random_state = 42)

# %%
train_files_full = Craw_train + Forw_train + Grab_train + Left_train + Papr_train + Righ_train + Rock_train + Scis_train + Uppp_train + Wave_train
test_files = Craw_test + Forw_test + Grab_test + Left_test + Papr_test + Righ_test + Rock_test + Scis_test + Uppp_test + Wave_test

# %%
train_files, val_files = train_test_split(train_files_full, test_size = .25, random_state = 42)

# %% [markdown]
# **Next:**
# - We will randomize the ```training set``` and ```validation set```files.
# - There is no need to randomize ```test_set``` files.

# %%
train_files = np.random.choice(train_files,
                               size = len(train_files),
                               replace = False)

val_files = np.random.choice(val_files,
                             size = len(val_files),
                             replace = False)

# %%
print("Total files in trainig set = ", len(train_files)) # 75% from Craw + 75% from Forw + 75% from Grab + ...............+ 75% _____
print("Total files in the validation set = ", len(val_files))
print("Total files in test set = ", len(test_files))
# Out:
# Total files in trainig set =  2250
# Total files in the validation set =  750
# Total files in test set =  1000

# %% [markdown]
# # <h1 align="center">Data preprocessing for TensorFlow</h1>
#
# <p align="center">
# <img src="https://raw.githubusercontent.com/ShayanRiyaz/My-Technical-Workshops/master/Deep-Learning-Robotics-Workshop/assets/TensorFlow.png" width ="100">
# </p>

# %% [markdown]
# ### Write a generator that reads data in chunks and preprocesses it
#
# Generator are similar to functions with one important difference.
# - While functions produce all their outputs at once, generators produce their outputs one by one and that too when asked.
# - `yield` keyword converts a function into a generator.
# - Generators can run for a fixed number of times or indefinitely depending on the loop structure used inside it.
# - For out application, we will use a generator that runs indefinitely.

# %% [markdown]
# The following generator takes a list of file names as first input. The second argument is `batch_size`.
# - `Batch_size` determines how many files we will process at one go. This is determined by how much memory do we have. If all data can be loaded into memory, there is no need for generators.
# - In case our data size is huge, we can process chunks of it.
#
# As we will be solving a classification problem, we have to assign labels to each raw data. We will use following labels for convenience.
#
# |Class| Label|
# |-----|------|
# |Craw| 0|
# |Forw| 1|
# |Grab| 2|
# |Left| 3|
# |.......|  |
# |Uppp| 9|
#
#
#
# The generator will `yield` both data and labels.

# %%
import tensorflow as tf
from tensorflow.keras import layers
import pandas as pd
import re               # To match regular expression for extracting labels

# %%
 print(train_files[190][13:17])
# Out:
# Left

# %%
def tf_data_generator(file_list, batch_size = 20):
    i = 0
    while True:
        if i*batch_size >= len(file_list):
            i = 0
            np.random.shuffle(file_list)
        else:
            file_chunk = file_list[i*batch_size:(i+1)*batch_size]
            data = []
            labels = []
            label_classes = tf.constant(["Craw","Forw","Grab","Left","Pape","Righ","Rock","Scis","Uppp","Wave"]) # This line has changed.
            for file in file_chunk:
                temp = pd.read_csv(open(file,'r'), header = None)
                data.append(temp.values)
                pattern = tf.constant(eval("file[13:17]"))  # This line has changed
                for j in range(len(label_classes)):
                    if re.match(pattern.numpy(), label_classes[j].numpy()):  # This line has changed.
                        labels.append(j)
            data = np.asarray(data).reshape(-1,20,10)
            labels = np.asarray(labels)
            yield data, labels
            i = i + 1

# %%
batch_size = 20
train_dataset = tf.data.Dataset.from_generator(tf_data_generator, args = [train_files, batch_size],
                                              output_shapes = ((None,20,10),(None,)),
                                              output_types = (tf.float32, tf.float32))

val_dataset = tf.data.Dataset.from_generator(tf_data_generator, args = [val_files, batch_size],
                                              output_shapes = ((None,20,10),(None,)),
                                              output_types = (tf.float32, tf.float32))

test_dataset = tf.data.Dataset.from_generator(tf_data_generator, args = [test_files, batch_size],
                                             output_shapes = ((None,20,10),(None,)),
                                             output_types = (tf.float32, tf.float32))
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_1172/2190403223.py:2: calling DatasetV2.from_generator (from tensorflow.python.data.ops.dataset_ops) with output_types is deprecated and will be removed in a future version.
# Instructions for updating:
# Use output_signature instead
# WARNING:tensorflow:From /tmp/ipykernel_1172/2190403223.py:2: calling DatasetV2.from_generator (from tensorflow.python.data.ops.dataset_ops) with output_shapes is deprecated and will be removed in a future version.
# Instructions for updating:
# Use output_signature instead

# %%
print(f'Train Dataset: \n{train_dataset}')
print(f'Validation Dataset: \n{val_dataset}')
print(f'Test Dataset: \n{test_dataset}')
# Out:
# Train Dataset:
# <_FlatMapDataset element_spec=(TensorSpec(shape=(None, 20, 10), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))>
# Validation Dataset:
# <_FlatMapDataset element_spec=(TensorSpec(shape=(None, 20, 10), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))>
# Test Dataset:
# <_FlatMapDataset element_spec=(TensorSpec(shape=(None, 20, 10), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))>

# %% [markdown]
# # <h1 align="center">TensorFlow-Keras Model Training</h1>
#
# <p align="center">
# <img src="https://raw.githubusercontent.com/ShayanRiyaz/My-Technical-Workshops/master/Deep-Learning-Robotics-Workshop/assets/TensorFlow.png" width ="100">
# <img src="https://raw.githubusercontent.com/ShayanRiyaz/My-Technical-Workshops/master/Deep-Learning-Robotics-Workshop/assets/Keras.png"  width ="100">
#
#
# </p>

# %%
model = tf.keras.Sequential([
        layers.InputLayer(shape=(20, 10), name="input"),
        layers.Flatten(name="flatten"),
        layers.Dropout(0.2, name = "dropout1"),
        layers.Dense(128, activation="relu",name = "DenseOne"),
        layers.Dropout(0.2, name = "dropout2"),
        layers.Dense(256,activation = "relu", name = "DenseTwo"),
        layers.Dense(10, activation="softmax",name="output")
    ],
        name="DeepController")
model.summary()
# Out:
# Model: "DeepController"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout1 (Dropout)              │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ DenseOne (Dense)                │ (None, 128)            │        25,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout2 (Dropout)              │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ DenseTwo (Dense)                │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 61,322 (239.54 KB)
#  Trainable params: 61,322 (239.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
tf.keras.utils.plot_model(
    model,
    to_file="model.png",
    show_layer_names=True,
    rankdir="TB",
    expand_nested=True,
    dpi=96,
)

# %% [markdown]
# <p align="center">
# <img src="https://raw.githubusercontent.com/ShayanRiyaz/My-Technical-Workshops/master/Deep-Learning-Robotics-Workshop/assets/neural_net.gif" width ="450">
# <img src="https://raw.githubusercontent.com/ShayanRiyaz/My-Technical-Workshops/master/Deep-Learning-Robotics-Workshop/assets/Flatten.gif" width ="250">
# <img src="https://raw.githubusercontent.com/ShayanRiyaz/My-Technical-Workshops/master/Deep-Learning-Robotics-Workshop/assets/dropout.gif" width ="250">
# </p>
#
#                           Dense Neural Network                                 Flatten                            Dropout

# %%
print("Train_dataset: ",train_dataset)
print("Batch_Size: ", batch_size)
# Out:
# Train_dataset:  <_FlatMapDataset element_spec=(TensorSpec(shape=(None, 20, 10), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))>
# Batch_Size:  20

# %%
model.compile(loss = "sparse_categorical_crossentropy",
              optimizer = "adam",
              metrics = ["accuracy"])

# %% [markdown]
# ### Set `train_step` and `steps` for evaluation.

# %% [markdown]
# There are 2560 files in training set. Batch_size is 20. So if the generator runs 128 times, it will correspond to one epoch. Therefore, we should set `steps_per_epoch` to 128.
#
# For validation steps total number of validation files are 640 and batch size is 20. Therefore if we run the generator 32 times we will have one epoch. Therefore `validation_steps` should be 32.
#
# For our test set total number of files are 800. and batch size is 20 therefore 40 cycles = 1 epoch.
# Similarly, din `model.evaluate()`, `steps = 40`.

# %%
STEPS_PER_EPOCH = 128
EPOCHS = 20
VALIDATION_STEPS = 32

# %%
print("Train_dataset: ",train_dataset)
print("Batch_Size: ", batch_size)
print("steps_per_epoch: ", STEPS_PER_EPOCH)
print("epochs: ", EPOCHS)
print("Validation_data: ",val_dataset)
print("Validation_steps: ", VALIDATION_STEPS)
# Out:
# Train_dataset:  <_FlatMapDataset element_spec=(TensorSpec(shape=(None, 20, 10), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))>
# Batch_Size:  20
# steps_per_epoch:  128
# epochs:  20
# Validation_data:  <_FlatMapDataset element_spec=(TensorSpec(shape=(None, 20, 10), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.float32, name=None))>
# Validation_steps:  32

# %% [markdown]
# ## Take 1

# %%
history = model.fit(train_dataset,
                    steps_per_epoch = STEPS_PER_EPOCH, # steps_per_epoch = batch_size*steps
                    epochs = EPOCHS,
                    validation_data = val_dataset,
                    validation_steps = VALIDATION_STEPS # validation_steps = batch_size*steps
                    )
# Out:
# Epoch 1/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.6757 - loss: 12.5794 - val_accuracy: 0.9031 - val_loss: 1.3747
# Epoch 2/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 141ms/step - accuracy: 0.8263 - loss: 2.8660 - val_accuracy: 0.9438 - val_loss: 0.5808
# Epoch 3/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 144ms/step - accuracy: 0.8553 - loss: 1.9383 - val_accuracy: 0.9547 - val_loss: 0.1712
# Epoch 4/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 150ms/step - accuracy: 0.8631 - loss: 1.6500 - val_accuracy: 0.9438 - val_loss: 0.1258
# Epoch 5/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 20s 161ms/step - accuracy: 0.8839 - loss: 1.0813 - val_accuracy: 0.9641 - val_loss: 0.2158
# Epoch 6/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 20s 158ms/step - accuracy: 0.8894 - loss: 1.1324 - val_accuracy: 0.9484 - val_loss: 0.4371
# Epoch 7/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 135ms/step - accuracy: 0.8957 - loss: 0.8842 - val_accuracy: 0.9438 - val_loss: 0.1600
# Epoch 8/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 139ms/step - accuracy: 0.8882 - loss: 1.2761 - val_accuracy: 0.9453 - val_loss: 0.2315
# Epoch 9/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 139ms/step - accuracy: 0.8988 - loss: 0.9433 - val_accuracy: 0.9094 - val_loss: 1.0984
# Epoch 10/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 20s 154ms/step - accuracy: 0.9012 - loss: 0.6919 - val_accuracy: 0.9484 - val_loss: 0.2105
# Epoch 11/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 148ms/step - accuracy: 0.9078 - loss: 0.6348 - val_accuracy: 0.9484 - val_loss: 0.1531
# Epoch 12/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 148ms/step - accuracy: 0.9137 - loss: 0.4606 - val_accuracy: 0.9703 - val_loss: 0.3149
# Epoch 13/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 138ms/step - accuracy: 0.9129 - loss: 0.5170 - val_accuracy: 0.9688 - val_loss: 0.0842
# Epoch 14/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 20s 157ms/step - accuracy: 0.9141 - loss: 0.5035 - val_accuracy: 0.9594 - val_loss: 0.0914
# Epoch 15/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 14s 112ms/step - accuracy: 0.9153 - loss: 0.5030 - val_accuracy: 0.9656 - val_loss: 0.1109
# Epoch 16/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 134ms/step - accuracy: 0.9177 - loss: 0.4039 - val_accuracy: 0.9656 - val_loss: 0.1593
# Epoch 17/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 132ms/step - accuracy: 0.9286 - loss: 0.4208 - val_accuracy: 0.9625 - val_loss: 0.1048
# Epoch 18/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 137ms/step - accuracy: 0.9267 - loss: 0.8608 - val_accuracy: 0.9625 - val_loss: 0.1274
# Epoch 19/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 143ms/step - accuracy: 0.9318 - loss: 0.3206 - val_accuracy: 0.9703 - val_loss: 0.1155
# Epoch 20/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 140ms/step - accuracy: 0.9196 - loss: 0.4537 - val_accuracy: 0.9531 - val_loss: 0.1047

# %%
TEST_STEPS = 40

# %%
test_loss, test_accuracy = model.evaluate(test_dataset,
                                          steps = TEST_STEPS)
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 104ms/step - accuracy: 0.9438 - loss: 0.1118

# %%
print("Test loss: ", test_loss)
print("Test accuracy:", test_accuracy)
# Out:
# Test loss:  0.11184437572956085
# Test accuracy: 0.9437500238418579

# %% [markdown]
# ### Plotting the Training and Validation

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1,len(acc) + 1)

plt.plot(epochs,acc,'b',label = 'Training acc')
plt.plot(epochs,val_acc,'r',label = 'Validation acc')
plt.title('Training Accuracy')
plt.legend()

plt.figure()

plt.plot(epochs,loss,'b',label = 'Training loss')
plt.plot(epochs,val_loss,'r',label = 'Validation loss')
plt.title('Training and Validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ## Take 2

# %%
model = tf.keras.Sequential([
        layers.InputLayer(shape=(20, 10), name="input"),
        layers.Flatten(name="flatten"),
        layers.Dropout(0.2, name = "dropout1"),
        layers.Dense(128, activation="relu",name = "DenseOne"),
        layers.Dropout(0.2, name = "dropout2"),
        layers.Dense(256,activation = "relu", name = "DenseTwo"),
        layers.Dense(10, activation="softmax",name="output")
    ],
        name="DeepController")
model.summary()
# Out:
# Model: "DeepController"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout1 (Dropout)              │ (None, 200)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ DenseOne (Dense)                │ (None, 128)            │        25,728 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout2 (Dropout)              │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ DenseTwo (Dense)                │ (None, 256)            │        33,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ output (Dense)                  │ (None, 10)             │         2,570 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 61,322 (239.54 KB)
#  Trainable params: 61,322 (239.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss = "sparse_categorical_crossentropy",
              optimizer = "adam",
              metrics = ["accuracy"])

# %%
def exponential_decay(lr0,s):
    def exponential_decay_fn(epoch):
        return lr0 * 0.1 **(epoch/s)
    return exponential_decay_fn


exponential_decay_fn = exponential_decay(0.01,20)

lr_scheduler = tf.keras.callbacks.LearningRateScheduler(exponential_decay_fn)

checkpoint_cb = tf.keras.callbacks.ModelCheckpoint('Gesture_Model.h5',
                                                  save_best_only = True)

early_stopping_cb = tf.keras.callbacks.EarlyStopping(patience = 10,
                                                    restore_best_weights = True)

# %%
history = model.fit(train_dataset,
                    steps_per_epoch = STEPS_PER_EPOCH, # steps_per_epoch = batch_size*steps
                    epochs = EPOCHS,
                    callbacks = [checkpoint_cb,early_stopping_cb,lr_scheduler],
                    validation_data = val_dataset,
                    validation_steps = VALIDATION_STEPS # validation_steps = batch_size*steps
                    )
# Out:
# Epoch 1/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.5920 - loss: 37.4736
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 22s 144ms/step - accuracy: 0.6800 - loss: 20.0523 - val_accuracy: 0.7156 - val_loss: 7.9460 - learning_rate: 0.0100
# Epoch 2/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7407 - loss: 9.7583
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 132ms/step - accuracy: 0.7369 - loss: 11.0674 - val_accuracy: 0.8031 - val_loss: 1.4684 - learning_rate: 0.0089
# Epoch 3/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 143ms/step - accuracy: 0.7502 - loss: 5.8979 - val_accuracy: 0.7656 - val_loss: 6.0786 - learning_rate: 0.0079
# Epoch 4/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 91ms/step - accuracy: 0.7505 - loss: 9.7416
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 152ms/step - accuracy: 0.7573 - loss: 8.9448 - val_accuracy: 0.7984 - val_loss: 0.9922 - learning_rate: 0.0071
# Epoch 5/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 21s 163ms/step - accuracy: 0.7678 - loss: 7.2879 - val_accuracy: 0.7719 - val_loss: 1.7541 - learning_rate: 0.0063
# Epoch 6/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 16s 125ms/step - accuracy: 0.7894 - loss: 2.9638 - val_accuracy: 0.7375 - val_loss: 5.2276 - learning_rate: 0.0056
# Epoch 7/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.7572 - loss: 5.4584
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 19s 146ms/step - accuracy: 0.7729 - loss: 3.2610 - val_accuracy: 0.8031 - val_loss: 0.5843 - learning_rate: 0.0050
# Epoch 8/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 75ms/step - accuracy: 0.7899 - loss: 0.7377
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 139ms/step - accuracy: 0.7898 - loss: 0.7761 - val_accuracy: 0.8359 - val_loss: 0.4265 - learning_rate: 0.0045
# Epoch 9/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 135ms/step - accuracy: 0.7961 - loss: 0.7179 - val_accuracy: 0.8328 - val_loss: 0.4331 - learning_rate: 0.0040
# Epoch 10/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8139 - loss: 0.5122
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 143ms/step - accuracy: 0.7973 - loss: 0.5486 - val_accuracy: 0.8125 - val_loss: 0.3879 - learning_rate: 0.0035
# Epoch 11/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 143ms/step - accuracy: 0.8031 - loss: 0.5210 - val_accuracy: 0.8422 - val_loss: 0.9508 - learning_rate: 0.0032
# Epoch 12/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 21s 162ms/step - accuracy: 0.8051 - loss: 0.6317 - val_accuracy: 0.8344 - val_loss: 0.4786 - learning_rate: 0.0028
# Epoch 13/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 15s 117ms/step - accuracy: 0.8125 - loss: 0.5024 - val_accuracy: 0.8516 - val_loss: 0.4519 - learning_rate: 0.0025
# Epoch 14/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 74ms/step - accuracy: 0.8089 - loss: 0.5491
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 136ms/step - accuracy: 0.8082 - loss: 0.5249 - val_accuracy: 0.8578 - val_loss: 0.3730 - learning_rate: 0.0022
# Epoch 15/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.8019 - loss: 0.5806
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 145ms/step - accuracy: 0.8071 - loss: 0.6632 - val_accuracy: 0.8547 - val_loss: 0.3666 - learning_rate: 0.0020
# Epoch 16/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 140ms/step - accuracy: 0.8118 - loss: 0.5396 - val_accuracy: 0.8578 - val_loss: 0.3736 - learning_rate: 0.0018
# Epoch 17/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 137ms/step - accuracy: 0.8114 - loss: 0.5464 - val_accuracy: 0.8516 - val_loss: 0.4125 - learning_rate: 0.0016
# Epoch 18/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step - accuracy: 0.8065 - loss: 0.5346
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 17s 136ms/step - accuracy: 0.8027 - loss: 0.5919 - val_accuracy: 0.8531 - val_loss: 0.3529 - learning_rate: 0.0014
# Epoch 19/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 140ms/step - accuracy: 0.8137 - loss: 0.6441 - val_accuracy: 0.8594 - val_loss: 0.3730 - learning_rate: 0.0013
# Epoch 20/20
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.8206 - loss: 0.4421
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 128/128 ━━━━━━━━━━━━━━━━━━━━ 18s 145ms/step - accuracy: 0.8196 - loss: 0.5007 - val_accuracy: 0.8594 - val_loss: 0.3459 - learning_rate: 0.0011

# %%
test_loss, test_accuracy = model.evaluate(test_dataset,
                                          steps = TEST_STEPS)
# Out:
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 4s 111ms/step - accuracy: 0.8138 - loss: 0.3246

# %%
print("Test loss: ", test_loss)
print("Test accuracy:", test_accuracy)
# Out:
# Test loss:  0.3245818316936493
# Test accuracy: 0.8137500286102295

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1,len(acc) + 1)

plt.plot(epochs,acc,'b',label = 'Training acc')
plt.plot(epochs,val_acc,'r',label = 'Validation acc')
plt.title('Training Accuracy')
plt.legend()

plt.figure()

plt.plot(epochs,loss,'b',label = 'Training loss')
plt.plot(epochs,val_loss,'r',label = 'Validation loss')
plt.title('Training and Validation loss')
plt.legend()

plt.show()

# %% [markdown]
# # <h1 align="center">Exporting the Model Using ONNX</h1>

# %% [markdown]
# <div class = "row" align="middle">
#   <div class="column">
# <img src="https://raw.githubusercontent.com/ShayanRiyaz/My-Technical-Workshops/master/Deep-Learning-Robotics-Workshop/assets/onnx.png" width="250" >
#   </div>
#
# </div>

# %% [markdown]
# ### Step 1: Convert the model into a frozen graph format.

# %%
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2
from pathlib import Path

# %%
Path("./models/").mkdir(parents=True, exist_ok=True)

# %%
# Save model to the native Keras format
model.save("./models/Gesture_Model.keras")

# %%
# Convert Keras model to ConcreteFunction
full_model = tf.function(lambda x: model(x))
full_model = full_model.get_concrete_function(
tf.TensorSpec(model.inputs[0].shape, model.inputs[0].dtype))

# %%
# Get frozen ConcreteFunction
frozen_func = convert_variables_to_constants_v2(full_model)
frozen_func.graph.as_graph_def()
# Out:
# node {
#   name: "x"
#   op: "Placeholder"
#   attr {
#     key: "shape"
#     value {
#       shape {
#         dim {
#           size
\305\264\270=\257\033\361=s\354\333<<\261\314=U\257\322=\263\261\303=\267\200\237=\n\007B>i\375A\276\231\204\236\275\230\243^=\234TA>.w\245=\005^F\276s\215\264\275.-\254\2755If\274w`\301<S\240\267\275\227\344&="\205\275\273f:S;M}\275=\307\\177=\277\025\203=\272t\324=n\222\027>4\307a<:t\001\276\356\351o<8\303\305;\301\221\226\275\235\300\375\2757q8\274\254\234\232=\322\365D>\366\276L\275\261|,<\235\353\177\276\000\201\204\2748\342\272<\216\354\014=\310*\252<\033\247Z\276\242\370R<=B\247>w\254\265\2716\344\211\274\320\223O>\365\377\242<J\206/\276%@\304\274A8\330\273_\364\200;\r\310"\276W\341\254=\220\243\340<x\245L=^|\005\276g\344j\276O\346\271=\262\324S\274\357F\277=\206S\346\275\260z\300\275\032w\030\2751\030\371\275\226\347\362=\215\222\217;\311\363\250\275\177v[=\2137b=_\033|>\256`\277\275|\221\004>\242\350.\276\250\353\205\275\247\303\245=\002\006_=\2177\320\273\304o\261=\266\346\225=\212\233a\275Z\2438\275d&\233={{L\2754\333\213\274\220H\271=c\027\313=\236\300e=\tK\263=\354\216\212=\224x\301\274\210\000\321<\365H\217=\360}\024>|\371\214=o\322\020>\335@'\276#\225==ev\250\273\277\261\313=\245\303v=U>\314=k\306U\275\257\332\264<\271\203R\275C\340\021\274\005c\365\275X\n\336\274'N\002=\361\306\323\275\217\3005\275p\313?\276\374\342\216=\215%\242\274\262\276\340=\252A\377;\347\237\217>4\202\n\275 HR\275G\303\262<\252\204^=\340\270\327\275\r@\365\274\220\362\024=g\255b\275\263\0179=\232\244\276\276\240n\n>\201\315%\275\343\255v>\005\237\224=}\256\254\276\3071\364=\364Ml\274\025\344\305=\376fd\276\0043\024\274\276\262u=\027u\020\276!\364Q\275\306\n\341=\256]\276\274?\314\311=\016\005\002=\330\0 ...
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "DeepController_1/output_1/BiasAdd/ReadVariableOp/resource"
#   op: "Const"
#   attr {
#     key: "value"
#     value {
#       tensor {
#         dtype: DT_FLOAT
#         tensor_shape {
#           dim {
#             size: 10
#           }
#         }
#         tensor_content: "|\225x\277\367\216q>\351\325\221\276\314\202\255=\312H9\277\340\nF\277PV)>\023\030\221\276\026j1?\005\016\377>"
#       }
#     }
#   }
#   attr {
#     key: "dtype"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "DeepController_1/flatten_1/Shape"
#   op: "Shape"
#   input: "x"
#   attr {
#     key: "out_type"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   experimental_type {
#     type_id: TFT_PRODUCT
#     args {
#       type_id: TFT_SHAPE_TENSOR
#       args {
#         type_id: TFT_INT32
#       }
#     }
#   }
# }
# node {
#   name: "DeepController_1/flatten_1/strided_slice"
#   op: "StridedSlice"
#   input: "DeepController_1/flatten_1/Shape"
#   input: "DeepController_1/flatten_1/strided_slice/stack"
#   input: "DeepController_1/flatten_1/strided_slice/stack_1"
#   input: "DeepController_1/flatten_1/strided_slice/stack_2"
#   attr {
#     key: "shrink_axis_mask"
#     value {
#       i: 1
#     }
#   }
#   attr {
#     key: "new_axis_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "end_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "ellipsis_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "begin_mask"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "Index"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "DeepController_1/flatten_1/Reshape/shape"
#   op: "Pack"
#   input: "DeepController_1/flatten_1/strided_slice"
#   input: "DeepController_1/flatten_1/Reshape/shape/1"
#   attr {
#     key: "axis"
#     value {
#       i: 0
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_INT32
#     }
#   }
#   attr {
#     key: "N"
#     value {
#       i: 2
#     }
#   }
# }
# node {
#   name: "DeepController_1/flatten_1/Reshape"
#   op: "Reshape"
#   input: "x"
#   input: "DeepController_1/flatten_1/Reshape/shape"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
#   attr {
#     key: "Tshape"
#     value {
#       type: DT_INT32
#     }
#   }
# }
# node {
#   name: "DeepController_1/DenseOne_1/Cast/ReadVariableOp"
#   op: "Identity"
#   input: "DeepController_1/DenseOne_1/Cast/ReadVariableOp/resource"
#   attr {
#     key: "_has_manual_control_dependencies"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "DeepController_1/DenseOne_1/MatMul"
#   op: "MatMul"
#   input: "DeepController_1/flatten_1/Reshape"
#   input: "DeepController_1/DenseOne_1/Cast/ReadVariableOp"
#   attr {
#     key: "transpose_b"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "transpose_a"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "grad_b"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "grad_a"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "DeepController_1/DenseOne_1/BiasAdd/ReadVariableOp"
#   op: "Identity"
#   input: "DeepController_1/DenseOne_1/BiasAdd/ReadVariableOp/resource"
#   attr {
#     key: "_has_manual_control_dependencies"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "DeepController_1/DenseOne_1/BiasAdd"
#   op: "BiasAdd"
#   input: "DeepController_1/DenseOne_1/MatMul"
#   input: "DeepController_1/DenseOne_1/BiasAdd/ReadVariableOp"
#   attr {
#     key: "data_format"
#     value {
#       s: "NHWC"
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "DeepController_1/DenseOne_1/Relu"
#   op: "Relu"
#   input: "DeepController_1/DenseOne_1/BiasAdd"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "DeepController_1/DenseTwo_1/Cast/ReadVariableOp"
#   op: "Identity"
#   input: "DeepController_1/DenseTwo_1/Cast/ReadVariableOp/resource"
#   attr {
#     key: "_has_manual_control_dependencies"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "DeepController_1/DenseTwo_1/MatMul"
#   op: "MatMul"
#   input: "DeepController_1/DenseOne_1/Relu"
#   input: "DeepController_1/DenseTwo_1/Cast/ReadVariableOp"
#   attr {
#     key: "transpose_b"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "transpose_a"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "grad_b"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "grad_a"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "DeepController_1/DenseTwo_1/BiasAdd/ReadVariableOp"
#   op: "Identity"
#   input: "DeepController_1/DenseTwo_1/BiasAdd/ReadVariableOp/resource"
#   attr {
#     key: "_has_manual_control_dependencies"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "DeepController_1/DenseTwo_1/BiasAdd"
#   op: "BiasAdd"
#   input: "DeepController_1/DenseTwo_1/MatMul"
#   input: "DeepController_1/DenseTwo_1/BiasAdd/ReadVariableOp"
#   attr {
#     key: "data_format"
#     value {
#       s: "NHWC"
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "DeepController_1/DenseTwo_1/Relu"
#   op: "Relu"
#   input: "DeepController_1/DenseTwo_1/BiasAdd"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "DeepController_1/output_1/Cast/ReadVariableOp"
#   op: "Identity"
#   input: "DeepController_1/output_1/Cast/ReadVariableOp/resource"
#   attr {
#     key: "_has_manual_control_dependencies"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "DeepController_1/output_1/MatMul"
#   op: "MatMul"
#   input: "DeepController_1/DenseTwo_1/Relu"
#   input: "DeepController_1/output_1/Cast/ReadVariableOp"
#   attr {
#     key: "transpose_b"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "transpose_a"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "grad_b"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "grad_a"
#     value {
#       b: false
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "DeepController_1/output_1/BiasAdd/ReadVariableOp"
#   op: "Identity"
#   input: "DeepController_1/output_1/BiasAdd/ReadVariableOp/resource"
#   attr {
#     key: "_has_manual_control_dependencies"
#     value {
#       b: true
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "DeepController_1/output_1/BiasAdd"
#   op: "BiasAdd"
#   input: "DeepController_1/output_1/MatMul"
#   input: "DeepController_1/output_1/BiasAdd/ReadVariableOp"
#   attr {
#     key: "data_format"
#     value {
#       s: "NHWC"
#     }
#   }
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "DeepController_1/output_1/Softmax"
#   op: "Softmax"
#   input: "DeepController_1/output_1/BiasAdd"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# node {
#   name: "NoOp"
#   op: "NoOp"
#   input: "^DeepController_1/DenseOne_1/BiasAdd/ReadVariableOp"
#   input: "^DeepController_1/DenseOne_1/Cast/ReadVariableOp"
#   input: "^DeepController_1/DenseTwo_1/BiasAdd/ReadVariableOp"
#   input: "^DeepController_1/DenseTwo_1/Cast/ReadVariableOp"
#   input: "^DeepController_1/output_1/BiasAdd/ReadVariableOp"
#   input: "^DeepController_1/output_1/Cast/ReadVariableOp"
#   attr {
#     key: "_has_manual_control_dependencies"
#     value {
#       b: true
#     }
#   }
# }
# node {
#   name: "Identity"
#   op: "Identity"
#   input: "DeepController_1/output_1/Softmax"
#   input: "^NoOp"
#   attr {
#     key: "T"
#     value {
#       type: DT_FLOAT
#     }
#   }
# }
# versions {
#   producer: 2129
# }

# %%
layers = [op.name for op in frozen_func.graph.get_operations()]
print("-" * 50)
print("Frozen model layers: ")
for layer in layers:
    print(layer)
# Out:
# --------------------------------------------------
# Frozen model layers:
# x
# DeepController_1/flatten_1/strided_slice/stack
# DeepController_1/flatten_1/strided_slice/stack_1
# DeepController_1/flatten_1/strided_slice/stack_2
# DeepController_1/flatten_1/Reshape/shape/1
# DeepController_1/DenseOne_1/Cast/ReadVariableOp/resource
# DeepController_1/DenseOne_1/BiasAdd/ReadVariableOp/resource
# DeepController_1/DenseTwo_1/Cast/ReadVariableOp/resource
# DeepController_1/DenseTwo_1/BiasAdd/ReadVariableOp/resource
# DeepController_1/output_1/Cast/ReadVariableOp/resource
# DeepController_1/output_1/BiasAdd/ReadVariableOp/resource
# DeepController_1/flatten_1/Shape
# DeepController_1/flatten_1/strided_slice
# DeepController_1/flatten_1/Reshape/shape
# DeepController_1/flatten_1/Reshape
# DeepController_1/DenseOne_1/Cast/ReadVariableOp
# DeepController_1/DenseOne_1/MatMul
# DeepController_1/DenseOne_1/BiasAdd/ReadVariableOp
# DeepController_1/DenseOne_1/BiasAdd
# DeepController_1/DenseOne_1/Relu
# DeepController_1/DenseTwo_1/Cast/ReadVariableOp
# DeepController_1/DenseTwo_1/MatMul
# DeepController_1/DenseTwo_1/BiasAdd/ReadVariableOp
# DeepController_1/DenseTwo_1/BiasAdd
# DeepController_1/DenseTwo_1/Relu
# DeepController_1/output_1/Cast/ReadVariableOp
# DeepController_1/output_1/MatMul
# DeepController_1/output_1/BiasAdd/ReadVariableOp
# DeepController_1/output_1/BiasAdd
# DeepController_1/output_1/Softmax
# NoOp
# Identity

# %%
print("-" * 50)
print("Frozen model inputs: ")
print(frozen_func.inputs)
print("Frozen model outputs: ")
print(frozen_func.outputs)
# Out:
# --------------------------------------------------
# Frozen model inputs:
# [<tf.Tensor 'x:0' shape=(None, 20, 10) dtype=float32>]
# Frozen model outputs:
# [<tf.Tensor 'Identity:0' shape=(None, 10) dtype=float32>]

# %%
# Save frozen graph from frozen ConcreteFunction to hard drive
tf.io.write_graph(graph_or_graph_def=frozen_func.graph,
                  logdir="./frozen_models",
                  name="frozen_graph.pb",
                  as_text=False)
# Out:
# './frozen_models/frozen_graph.pb'

# %% [markdown]
# ### Step 2 : Convert the Frozen graph model to an ONNX file

# %%
# !git clone https://github.com/onnx/tensorflow-onnx
# Out:
# Cloning into 'tensorflow-onnx'...
# remote: Enumerating objects: 17854, done.
# remote: Counting objects: 100% (2562/2562), done.
# remote: Compressing objects: 100% (341/341), done.
# remote: Total 17854 (delta 2369), reused 2221 (delta 2221), pack-reused 15292 (from 4)
# Receiving objects: 100% (17854/17854), 32.09 MiB | 26.23 MiB/s, done.
# Resolving deltas: 100% (13289/13289), done.

# %%
# !python setup.py install
# Out:
# python3: can't open file '/content/setup.py': [Errno 2] No such file or directory

# %%
 # !python -m tf2onnx.convert --input "frozen_models/frozen_graph.pb" --output model.onnx --outputs Identity:0 --inputs x:0
# Out:
# /usr/bin/python3: Error while finding module specification for 'tf2onnx.convert' (ModuleNotFoundError: No module named 'tf2onnx')

# %% [markdown]
# # <h1 align="center">Inference in Unity</h1>

# %% [markdown]
# <div class = "row" align="middle">
#   <div class="column">
# <img src="https://raw.githubusercontent.com/ShayanRiyaz/My-Technical-Workshops/master/Deep-Learning-Robotics-Workshop/assets/Unity.png" width="100" >
#   </div>
#
# </div>

# %% [markdown]
# ```
# // C#
#     void RunningModel()
#     {
#         m_RuntimeModel = ModelLoader.Load(m_Model);
#         m_Worker = WorkerFactory.CreateWorker(WorkerFactory.Type.CSharp, m_RuntimeModel);
#
#         m_input = new Tensor(20, 10, f_data);
#
#         m_Worker.Execute(m_input);
#         Tensor result = m_Worker.CopyOutput();
#
#         float maxResult = 0.0f;
#         for (int i = 0; i < 10; ++i)
#         {
#             if (result[i] > maxResult)
#             {
#                 maxResult = result[i];
#                 maxIndex = i;
#             }
#         }
#     }
# ```

# %%
# !pip install fpdf
import pandas as pd
from fpdf import FPDF

# Create a PDF class to handle the report generation
class ProjectReport(FPDF):
    def header(self):
        self.set_font('Arial', 'B', 15)
        self.cell(0, 10, 'Assignment Report: Deep Learning and Robotics', 0, 1, 'C')
        self.ln(10)

    def chapter_title(self, title):
        self.set_font('Arial', 'B', 12)
        self.cell(0, 10, title, 0, 1, 'L')
        self.ln(4)

    def chapter_body(self, body):
        self.set_font('Arial', '', 11)
        self.multi_cell(0, 10, body)
        self.ln()

# Initialize PDF
pdf = ProjectReport()
pdf.add_page()

# Objective
pdf.chapter_title('1. Objective')
pdf.chapter_body('The primary objective of this project is to develop a "Narrow AI" model capable of classifying hand gestures using data from custom-built Inertial Measurement Units (IMUs). This model serves as a controller for a Unity-based game, utilizing Sensor Fusion and TensorFlow to bridge the gap between robotics and deep learning.')

# Data Preprocessing
pdf.chapter_title('2. Data Preprocessing and Ingestion')
pdf.chapter_body('Data was collected for 10 distinct gesture classes (Crawl, Forward, Grab, Left, Paper, Right, Rock, Scissors, Up, Wave). The preprocessing pipeline involved:\n- Extracting and unzipping raw CSV data from Google Drive.\n- Splitting the dataset into Training (75%), Validation (approx 18%), and Test (approx 25%) sets.\n- Implementing a custom TensorFlow data generator to handle file reading in batches (Batch Size: 20) and label extraction.')

# Model Architecture
pdf.chapter_title('3. Model Architecture')
pdf.chapter_body('A Sequential Deep Learning model was built using Keras with the following layers:\n- Input Layer (20, 10)\n- Flatten Layer\n- Dense Layers (128 and 256 units with ReLU activation)\n- Dropout Layers (0.2) for regularization to prevent overfitting\n- Output Layer (10 units with Softmax activation)')

# Training Results
pdf.chapter_title('4. Training and Evaluation')
pdf.chapter_body('The model was trained over 20 epochs. In the initial evaluation, the model achieved:\n- Test Accuracy: ~94.37%\n- Test Loss: ~0.1118\nA second iteration utilized learning rate exponential decay and early stopping to optimize convergence.')

# Exporting the Model
pdf.chapter_title('5. Model Export and Deployment')
pdf.chapter_body('To facilitate inference within the Unity game engine:\n- The Keras model was converted to a ConcreteFunction.\n- The variables were frozen into a Frozen Graph (.pb format).\n- The project prepared for ONNX conversion to allow the Unity Barracuda engine to run the model in C#.')

# Output the PDF
pdf.output('Project_Assignment_Summary.pdf')
print('PDF report generated successfully: Project_Assignment_Summary.pdf')
# Out:
# Collecting fpdf
#   Downloading fpdf-1.7.2.tar.gz (39 kB)
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: fpdf
#   Building wheel for fpdf (setup.py) ... done
#   Created wheel for fpdf: filename=fpdf-1.7.2-py2.py3-none-any.whl size=40704 sha256=0cc646c915afb0c9f1f8b755d21e21765fb912f78404f0209e8f4619e132b1c3
#   Stored in directory: /root/.cache/pip/wheels/6e/62/11/dc73d78e40a218ad52e7451f30166e94491be013a7850b5d75
# Successfully built fpdf
# Installing collected packages: fpdf
# Successfully installed fpdf-1.7.2
# PDF report generated successfully: Project_Assignment_Summary.pdf

# %%
import os
if os.path.exists('/content/drive/MyDrive'):
    # !cp Project_Assignment_Summary.pdf /content/drive/MyDrive/Project_Assignment_Summary.pdf
    print('PDF successfully copied to Google Drive!')
else:
    print('Error: Google Drive not found. Please ensure it is mounted.')
# Out:
# cp: cannot create regular file '/content/drive/MyDrive/': No such file or directory
# PDF successfully copied to Google Drive!

# %% [markdown]
# Books I would recommend:
# - [Hands on Machine Learning with Sci-kit Learn and Tensorflow](https://www.oreilly.com/library/view/hands-on-machine-learning/9781492032632/)
# - [Building Machine Learning Pipelines](https://www.oreilly.com/library/view/building-machine-learning/9781492053187/)
# - [Deep Learning for Coders with fastai and PyTorch](https://www.oreilly.com/library/view/deep-learning-for/9781492045519/)

# %% [markdown]
# ### Check out this video below. It was by a MLH Fellow from a previous batch. (Click On the Julia image)

# %% [markdown]
# [![Everything Is AWESOME](https://upload.wikimedia.org/wikipedia/commons/thumb/1/1f/Julia_Programming_Language_Logo.svg/220px-Julia_Programming_Language_Logo.svg.png)](https://www.youtube.com/watch?v=2yrWGtQ9_Yo "Everything Is AWESOME")

# %% [markdown]
# # Resources:
# - [Efficiently Reading Multiple Files in TensorFlow](https://biswajitsahoo1111.github.io/post/efficiently-reading-multiple-files-in-tensorflow-2/)
# - [Save Load Inference from TF2 Frozen Graph](https://leimao.github.io/blog/Save-Load-Inference-From-TF2-Frozen-Graph/)
# - [What is an IMU sensor](https://www.ceva-dsp.com/ourblog/what-is-an-imu-sensor/)
# - [Narrow AI](https://deepai.org/machine-learning-glossary-and-terms/narrow-ai)
